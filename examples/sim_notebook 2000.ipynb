# %%
import sims
import pandas as pd

# %%
file_name = "IREC_version1"
motor_name = "AeroTech_N2000W"

file = sims.File_simulation(file_name, motor_name)
# Out:
# File and motor verified
# Creating rocket for IREC_version1 with motor AeroTech_N2000W
# Rocket created and ready for simulation. WARNING: Parachutes not added.

# %%
file.graph_motor()
file.show_motor_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.03675 m
# Nozzle Throat Radius: 0.01 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0.0 m
# Grain Density: 1269.4646112306802 kg/m3
# Grain Outer Radius: 0.049 m
# Grain Inner Radius: 0.0245 m
# Grain Height: 1.046 m
# Grain Volume: 0.006 m3
# Grain Mass: 7.512 kg
#
# Motor Details
# Total Burning Time: 7.679 s
# Total Propellant Mass: 7.512 kg
# Structural Mass Ratio: 0.376
# Average Propellant Exhaust Velocity: 1765.634 m/s
# Average Thrust: 1727.236 N
# Maximum Thrust: 2834.354 N at 0.746 s after ignition.
# Total Impulse: 13263.442 Ns

# %%
file.graph_rocket()
file.show_rocket_info()
# Out:
# Inertia Details
#
# Rocket Mass: 20.272 kg (without motor)
# Rocket Dry Mass: 24.799 kg (with unloaded motor)
# Rocket Loaded Mass: 32.311 kg
# Rocket Structural Mass Ratio: 0.768
# Rocket Inertia (with unloaded motor) 11: 6.800 kg*m2
# Rocket Inertia (with unloaded motor) 22: 6.800 kg*m2
# Rocket Inertia (with unloaded motor) 33: 40.367 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0875 m
# Rocket Frontal Area: 0.024053 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.189 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.371 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.848 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.197 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 8.215/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.438 m
# Fins Center of Pressure position: 2.927 m
#
# Stability
#
# Center of Mass position (time=0): 1.916 m
# Center of Pressure position (time=0): 2.440 m
# Initial Static Margin (mach=0, time=0): 2.992 c
# Final Static Margin (mach=0, time=burn_out): 4.118 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.524 m

# %%
lat = 40.4168
lon = -3.7038
elev = 667  # Elevation in meters

env1 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=5)
env2 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=10)
env3 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=15)
env4 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=20)

envs = [env1, env2, env3, env4]
envs_names = ['0 deg', '90 deg', '180 deg', '270 deg']
rail_lengths = [5.7]
inclinations = [0]
headings = [0]
elevations = [0]


multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=envs_names,
    rail_lengths=rail_lengths,
    inclinations=inclinations,
    headings=headings,
    elevations=elevations
)

df = sims.compare_usual_important_data(multiple_files, keys)
# Out:
# Runnin sim0
# Simulation 0 completed
# Runnin sim1
# Simulation 1 completed
# Runnin sim2
# Simulation 2 completed
# Runnin sim3
# Simulation 3 completed

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
df
# Out:
#                                      ENV_0 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                               2.992
# frontal_surface_wind [m/s]                                     5.000
# lateral_surface_wind [m/s]                                     0.000
# out_rail_vel [m/s]                                            27.356
# out_rail_stability [calibers]                                  3.061
# out_rail_angle_of_attack [deg]                                10.358
# out_rail_thrust_to_weight [ratio]                              9.091
# burn_out_dynamic_pressure [Pa]                             40112.007
# burn_out_time [s]                                              7.679
# burn_out_accel [m/s²]                                         27.789
# apogee_alt [m]                                              4111.483
# apogee_time [s]                                               28.179
# max_speed [m/s]                                              327.146
# max_speed_time [s]                                             5.656
# max_mach [-]                                                   0.984
# max_mach_time [s]                                              5.721
# max_dynamic_pressure [Pa]                                  55612.383
# max_dynamic_pressure_time [s]                                  5.537
# max_acceleration_power_on [m/s²]                              81.133
# max_acceleration_power_on_time [s]                             1.044
# max_Gs_power_on [G]                                            8.273
# max_Gs_power_on_time [s]                                       1.044
# max_acceleration_power_off [m/s²]                              0.000
# max_acceleration_power_off_time [s]                            0.000
# max_Gs_power_off [G]                                           0.000
# max_Gs_power_off_time [s]                                      0.000
# max_stability_margin [calibers]                                4.427
# impact_speed [m/s]                                           189.415
# impact_time [s]                                               61.446
#
#                                      ENV_90 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                2.992
# frontal_surface_wind [m/s]                                     10.000
# lateral_surface_wind [m/s]                                      0.000
# out_rail_vel [m/s]                                             27.354
# out_rail_stability [calibers]                                   3.062
# out_rail_angle_of_attack [deg]                                 20.082
# out_rail_thrust_to_weight [ratio]                               9.091
# burn_out_dynamic_pressure [Pa]                              40768.845
# burn_out_time [s]                                               7.679
# burn_out_accel [m/s²]                                          27.829
# apogee_alt [m]                                               3893.180
# apogee_time [s]                                                27.351
# max_speed [m/s]                                               326.465
# max_speed_time [s]                                              5.656
# max_mach [-]                                                    0.989
# max_mach_time [s]                                               5.713
# max_dynamic_pressure [Pa]                                   56269.664
# max_dynamic_pressure_time [s]                                   5.536
# max_acceleration_power_on [m/s²]                               81.595
# max_acceleration_power_on_time [s]                              1.040
# max_Gs_power_on [G]                                             8.320
# max_Gs_power_on_time [s]                                        1.040
# max_acceleration_power_off [m/s²]                               0.000
# max_acceleration_power_off_time [s]                             0.000
# max_Gs_power_off [G]                                            0.000
# max_Gs_power_off_time [s]                                       0.000
# max_stability_margin [calibers]                                 4.427
# impact_speed [m/s]                                            186.841
# impact_time [s]                                                59.749
#
#                                      ENV_180 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                 2.992
# frontal_surface_wind [m/s]                                      15.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              27.349
# out_rail_stability [calibers]                                    3.062
# out_rail_angle_of_attack [deg]                                  28.743
# out_rail_thrust_to_weight [ratio]                                9.091
# burn_out_dynamic_pressure [Pa]                               41823.643
# burn_out_time [s]                                                7.679
# burn_out_accel [m/s²]                                           27.878
# apogee_alt [m]                                                3568.557
# apogee_time [s]                                                 26.140
# max_speed [m/s]                                                325.403
# max_speed_time [s]                                               5.657
# max_mach [-]                                                     0.995
# max_mach_time [s]                                                5.716
# max_dynamic_pressure [Pa]                                    57326.773
# max_dynamic_pressure_time [s]                                    5.557
# max_acceleration_power_on [m/s²]                                82.328
# max_acceleration_power_on_time [s]                               1.040
# max_Gs_power_on [G]                                              8.395
# max_Gs_power_on_time [s]                                         1.040
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.000
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.000
# max_stability_margin [calibers]                                  4.427
# impact_speed [m/s]                                             182.762
# impact_time [s]                                                 57.122
#
#                                      ENV_270 deg_RL5.7_INC0_HDG0_ELEV0
# Variable
# initial_static_margin [calibers]                                 2.993
# frontal_surface_wind [m/s]                                      20.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              27.344
# out_rail_stability [calibers]                                    3.063
# out_rail_angle_of_attack [deg]                                  36.183
# out_rail_thrust_to_weight [ratio]                                9.091
# burn_out_dynamic_pressure [Pa]                               43207.129
# burn_out_time [s]                                                7.679
# burn_out_accel [m/s²]                                           27.970
# apogee_alt [m]                                                3180.862
# apogee_time [s]                                                 24.689
# max_speed [m/s]                                                324.025
# max_speed_time [s]                                               5.646
# max_mach [-]                                                     1.004
# max_mach_time [s]                                                5.698
# max_dynamic_pressure [Pa]                                    58727.507
# max_dynamic_pressure_time [s]                                    5.572
# max_acceleration_power_on [m/s²]                                83.263
# max_acceleration_power_on_time [s]                               1.018
# max_Gs_power_on [G]                                              8.490
# max_Gs_power_on_time [s]                                         1.018
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.000
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.000
# max_stability_margin [calibers]                                  4.427
# impact_speed [m/s]                                             177.341
# impact_time [s]                                                 53.847

# %%
multiple_files[keys[0]].plots.trajectory_3d()

# %%
env1.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8000 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5598 m/s²
#
#
# Launch Site Details
#
# Launch Site Latitude: 40.41680°
# Launch Site Longitude: -3.70380°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 440290.46 W    4474257.38 N
# Launch Site UTM zone: 30T
# Launch Site Surface Elevation: 667.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: custom_atmosphere
# custom_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 5.00 m/s
# Surface Wind Direction: 180.00°
# Surface Wind Heading: 360.00°
# Surface Pressure: 935.78 hPa
# Surface Temperature: 283.82 K
# Surface Air Density: 1.149 kg/m³
# Surface Speed of Sound: 337.56 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.19 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
