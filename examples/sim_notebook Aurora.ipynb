# %%
import sims
import pandas as pd
from rocketpy import Environment

# %%
file_name = "AURORA_v02"
motor_name = "Volta_motor_v1"

file = sims.File_simulation(file_name, motor_name)
# Out:
# File and motor verified
# Creating rocket for AURORA_v02 with motor Volta_motor_v1
# Rocket created and ready for simulation

# %%
file.graph_motor()
file.show_motor_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.03675 m
# Nozzle Throat Radius: 0.01 m
#
# Grain Details
# Number of Grains: 5
# Grain Spacing: 0.015 m
# Grain Density: 1749.8 kg/m3
# Grain Outer Radius: 0.067 m
# Grain Inner Radius: 0.0225 m
# Grain Height: 0.21 m
# Grain Volume: 0.003 m3
# Grain Mass: 4.598 kg
#
# Motor Details
# Total Burning Time: 5.82 s
# Total Propellant Mass: 22.988 kg
# Structural Mass Ratio: 0.291
# Average Propellant Exhaust Velocity: 1148.018 m/s
# Average Thrust: 4534.574 N
# Maximum Thrust: 5042.5879 N at 2.46 s after ignition.
# Total Impulse: 26391.219 Ns

# %%
file.graph_rocket()
file.show_rocket_info()
# Out:
# Inertia Details
#
# Rocket Mass: 21.507 kg (without motor)
# Rocket Dry Mass: 30.949 kg (with unloaded motor)
# Rocket Loaded Mass: 53.937 kg
# Rocket Structural Mass Ratio: 0.574
# Rocket Inertia (with unloaded motor) 11: 10.702 kg*m2
# Rocket Inertia (with unloaded motor) 22: 10.702 kg*m2
# Rocket Inertia (with unloaded motor) 33: 35.882 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0875 m
# Rocket Frontal Area: 0.024053 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.385 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.405 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.735 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.313 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 9.733/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.438 m
# Fins Center of Pressure position: 3.374 m
#
# Stability
#
# Center of Mass position (time=0): 2.428 m
# Center of Pressure position (time=0): 2.873 m
# Initial Static Margin (mach=0, time=0): 2.543 c
# Final Static Margin (mach=0, time=burn_out): 4.332 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.445 m
#
#
# Parachute Details
#
# Parachute Main Parachute with a cd_s of 33.0633 m2
# Ejection signal trigger: 450.0 m (AGL)
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.0 s
#
#
# Parachute Details
#
# Parachute Drogue Parachute with a cd_s of 1.3701 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.0 s

# %% [markdown]
# # Site 1

# %%
lat = 12.2830555556
lon = -71.9100000000
elev = 13  # Elevation in meters

env0 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=0)
env1 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=5)
env2 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=10)
env3 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=15)
env4 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=20)

env5 = Environment(
    date=(2019, 8, 10, 15),
    latitude= lat,
    longitude= lon,
    elevation= elev,
)

envs = [env2]
env_names = ["normal"]
rail_lengths = [5.2] # Longitud del riel en metros
inclinations = [3] # Inclinación del riel en grados
headings = [0, 90, 270, 45] # Rumbo del riel en grados
elevations = [elev] 


multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=env_names,
    rail_lengths=rail_lengths,
    inclinations=inclinations,
    headings=headings,
    elevations=elevations
)

df = sims.compare_usual_important_data(multiple_files, keys)
# Out:
# Runnin sim0
# Simulation 0 completed
# Runnin sim1
# Simulation 1 completed
# Runnin sim2
# Simulation 2 completed
# Runnin sim3
# Simulation 3 completed

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
df
# Out:
#                                      ENV_normal_RL5.2_INC3_HDG0_ELEV13  \
# Variable
# initial_static_margin [calibers]                                 2.544
# frontal_surface_wind [m/s]                                      -0.000
# lateral_surface_wind [m/s]                                      10.000
# out_rail_vel [m/s]                                              25.118
# out_rail_stability [calibers]                                    2.606
# out_rail_angle_of_attack [deg]                                  21.708
# out_rail_thrust_to_weight [ratio]                                8.956
# burn_out_dynamic_pressure [Pa]                              127088.019
# burn_out_time [s]                                                5.820
# burn_out_accel [m/s²]                                           53.480
# apogee_alt [m]                                                5983.713
# apogee_time [s]                                                 32.715
# max_speed [m/s]                                                486.873
# max_speed_time [s]                                               5.795
# max_mach [-]                                                     1.465
# max_mach_time [s]                                                5.795
# max_dynamic_pressure [Pa]                                   127532.613
# max_dynamic_pressure_time [s]                                    5.794
# max_acceleration_power_on [m/s²]                               100.548
# max_acceleration_power_on_time [s]                               3.086
# max_Gs_power_on [G]                                             10.253
# max_Gs_power_on_time [s]                                         3.086
# max_acceleration_power_off [m/s²]                              100.107
# max_acceleration_power_off_time [s]                              3.425
# max_Gs_power_off [G]                                            10.208
# max_Gs_power_off_time [s]                                        3.425
# max_stability_margin [calibers]                                  4.694
# impact_speed [m/s]                                              10.724
# impact_time [s]                                                398.101
# impact_x [m]                                                 -1057.782
# impact_y [m]                                                   663.180
# impact_lat [°]                                                  12.289
# impact_lon [°]                                                 -71.920
# impact_radius [m]                                             1248.484
#
#                                      ENV_normal_RL5.2_INC3_HDG90_ELEV13  \
# Variable
# initial_static_margin [calibers]                                  2.544
# frontal_surface_wind [m/s]                                      -10.000
# lateral_surface_wind [m/s]                                        0.000
# out_rail_vel [m/s]                                               25.118
# out_rail_stability [calibers]                                     2.607
# out_rail_angle_of_attack [deg]                                   21.279
# out_rail_thrust_to_weight [ratio]                                 8.956
# burn_out_dynamic_pressure [Pa]                               127826.787
# burn_out_time [s]                                                 5.820
# burn_out_accel [m/s²]                                            52.465
# apogee_alt [m]                                                 5791.762
# apogee_time [s]                                                  32.137
# max_speed [m/s]                                                 487.099
# max_speed_time [s]                                                5.799
# max_mach [-]                                                      1.467
# max_mach_time [s]                                                 5.799
# max_dynamic_pressure [Pa]                                    128270.820
# max_dynamic_pressure_time [s]                                     5.793
# max_acceleration_power_on [m/s²]                                100.654
# max_acceleration_power_on_time [s]                                3.074
# max_Gs_power_on [G]                                              10.264
# max_Gs_power_on_time [s]                                          3.074
# max_acceleration_power_off [m/s²]                                98.299
# max_acceleration_power_off_time [s]                               3.849
# max_Gs_power_off [G]                                             10.024
# max_Gs_power_off_time [s]                                         3.849
# max_stability_margin [calibers]                                   4.697
# impact_speed [m/s]                                               10.724
# impact_time [s]                                                 390.139
# impact_x [m]                                                   -438.196
# impact_y [m]                                                      0.000
# impact_lat [°]                                                   12.283
# impact_lon [°]                                                  -71.914
# impact_radius [m]                                               438.196
#
#                                      ENV_normal_RL5.2_INC3_HDG270_ELEV13  \
# Variable
# initial_static_margin [calibers]                                   2.544
# frontal_surface_wind [m/s]                                        10.000
# lateral_surface_wind [m/s]                                        -0.000
# out_rail_vel [m/s]                                                25.119
# out_rail_stability [calibers]                                      2.606
# out_rail_angle_of_attack [deg]                                    22.098
# out_rail_thrust_to_weight [ratio]                                  8.956
# burn_out_dynamic_pressure [Pa]                                126336.319
# burn_out_time [s]                                                  5.820
# burn_out_accel [m/s²]                                             54.752
# apogee_alt [m]                                                  6188.595
# apogee_time [s]                                                   33.336
# max_speed [m/s]                                                  486.673
# max_speed_time [s]                                                 5.798
# max_mach [-]                                                       1.463
# max_mach_time [s]                                                  5.800
# max_dynamic_pressure [Pa]                                     126783.127
# max_dynamic_pressure_time [s]                                      5.792
# max_acceleration_power_on [m/s²]                                 100.436
# max_acceleration_power_on_time [s]                                 3.090
# max_Gs_power_on [G]                                               10.242
# max_Gs_power_on_time [s]                                           3.090
# max_acceleration_power_off [m/s²]                                 49.355
# max_acceleration_power_off_time [s]                                5.438
# max_Gs_power_off [G]                                               5.033
# max_Gs_power_off_time [s]                                          5.438
# max_stability_margin [calibers]                                    4.721
# impact_speed [m/s]                                                10.724
# impact_time [s]                                                  406.475
# impact_x [m]                                                   -1718.908
# impact_y [m]                                                      -0.000
# impact_lat [°]                                                    12.283
# impact_lon [°]                                                   -71.926
# impact_radius [m]                                               1718.908
#
#                                      ENV_normal_RL5.2_INC3_HDG45_ELEV13
# Variable
# initial_static_margin [calibers]                                  2.544
# frontal_surface_wind [m/s]                                       -7.071
# lateral_surface_wind [m/s]                                        7.071
# out_rail_vel [m/s]                                               25.118
# out_rail_stability [calibers]                                     2.606
# out_rail_angle_of_attack [deg]                                   21.409
# out_rail_thrust_to_weight [ratio]                                 8.956
# burn_out_dynamic_pressure [Pa]                               127614.739
# burn_out_time [s]                                                 5.820
# burn_out_accel [m/s²]                                            54.539
# apogee_alt [m]                                                 5846.835
# apogee_time [s]                                                  32.303
# max_speed [m/s]                                                 487.042
# max_speed_time [s]                                                5.798
# max_mach [-]                                                      1.466
# max_mach_time [s]                                                 5.798
# max_dynamic_pressure [Pa]                                    128059.821
# max_dynamic_pressure_time [s]                                     5.793
# max_acceleration_power_on [m/s²]                                100.624
# max_acceleration_power_on_time [s]                                3.079
# max_Gs_power_on [G]                                              10.261
# max_Gs_power_on_time [s]                                          3.079
# max_acceleration_power_off [m/s²]                                99.880
# max_acceleration_power_off_time [s]                               3.520
# max_Gs_power_off [G]                                             10.185
# max_Gs_power_off_time [s]                                         3.520
# max_stability_margin [calibers]                                   4.718
# impact_speed [m/s]                                               10.724
# impact_time [s]                                                 392.459
# impact_x [m]                                                   -616.105
# impact_y [m]                                                    455.794
# impact_lat [°]                                                   12.287
# impact_lon [°]                                                  -71.916
# impact_radius [m]                                               766.377

# %%
for i, key in enumerate(keys):
    print(f"--- Simulation {i}: {key} ---")
    multiple_files[keys[i]].plots.trajectory_3d()
# Out:
# --- Simulation 0: ENV_normal_RL5.2_INC3_HDG0_ELEV13 ---
# --- Simulation 1: ENV_normal_RL5.2_INC3_HDG90_ELEV13 ---
# --- Simulation 2: ENV_normal_RL5.2_INC3_HDG270_ELEV13 ---
# --- Simulation 3: ENV_normal_RL5.2_INC3_HDG45_ELEV13 ---

# %%
for i, key in enumerate(keys):
    print(f"--- Simulation {i}: {key} ---")
    multiple_files[keys[i]].prints.impact_conditions()
# Out:
# --- Simulation 0: ENV_normal_RL5.2_INC3_HDG0_ELEV13 ---
#
# Impact Conditions
#
# Time of impact: 398.101 s
# X impact: -1057.782 m
# Y impact: 663.180 m
# Altitude impact: 13.000 m (ASL) | 0.000 m (AGL)
# Latitude: 12.2890137°
# Longitude: -71.9197265°
# Vertical velocity at impact: -3.873 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 1: ENV_normal_RL5.2_INC3_HDG90_ELEV13 ---
#
# Impact Conditions
#
# Time of impact: 390.139 s
# X impact: -438.196 m
# Y impact: 0.000 m
# Altitude impact: 13.000 m (ASL) | 0.000 m (AGL)
# Latitude: 12.2830555°
# Longitude: -71.9140292°
# Vertical velocity at impact: -3.873 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 2: ENV_normal_RL5.2_INC3_HDG270_ELEV13 ---
#
# Impact Conditions
#
# Time of impact: 406.475 s
# X impact: -1718.908 m
# Y impact: -0.000 m
# Altitude impact: 13.000 m (ASL) | 0.000 m (AGL)
# Latitude: 12.2830551°
# Longitude: -71.9258053°
# Vertical velocity at impact: -3.873 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 3: ENV_normal_RL5.2_INC3_HDG45_ELEV13 ---
#
# Impact Conditions
#
# Time of impact: 392.459 s
# X impact: -616.105 m
# Y impact: 455.794 m
# Altitude impact: 13.000 m (ASL) | 0.000 m (AGL)
# Latitude: 12.2871506°
# Longitude: -71.9156652°
# Vertical velocity at impact: -3.873 m/s
# Number of parachutes triggered until impact: 2

# %% [markdown]
# # Site 2

# %%
lat = 3.2316666667
lon = -75.1691666667
elev = 436  # Elevation in meters

env0 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=0)
env1 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=5)
env2 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=10)
env3 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=15)
env4 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=90, speed=20)

env5 = Environment(
    date=(2019, 8, 10, 15),
    latitude= lat,
    longitude= lon,
    elevation= elev,
)

envs = [env2]
env_names = ["normal"]
rail_lengths = [5.2] # Longitud del riel en metros
inclinations = [3] # Inclinación del riel en grados
headings = [0, 90, 270, 45] # Rumbo del riel en grados
elevations = [elev] 


multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=env_names,
    rail_lengths=rail_lengths,
    inclinations=inclinations,
    headings=headings,
    elevations=elevations
)

df = sims.compare_usual_important_data(multiple_files, keys)
# Out:
# Runnin sim0
# Simulation 0 completed
# Runnin sim1
# Simulation 1 completed
# Runnin sim2
# Simulation 2 completed
# Runnin sim3
# Simulation 3 completed

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
df
# Out:
#                                      ENV_normal_RL5.2_INC3_HDG0_ELEV436  \
# Variable
# initial_static_margin [calibers]                                  2.544
# frontal_surface_wind [m/s]                                       -0.000
# lateral_surface_wind [m/s]                                       10.000
# out_rail_vel [m/s]                                               25.122
# out_rail_stability [calibers]                                     2.606
# out_rail_angle_of_attack [deg]                                   21.705
# out_rail_thrust_to_weight [ratio]                                 8.956
# burn_out_dynamic_pressure [Pa]                               123384.286
# burn_out_time [s]                                                 5.820
# burn_out_accel [m/s²]                                            52.110
# apogee_alt [m]                                                 6137.977
# apogee_time [s]                                                  33.238
# max_speed [m/s]                                                 490.063
# max_speed_time [s]                                                5.795
# max_mach [-]                                                      1.482
# max_mach_time [s]                                                 5.795
# max_dynamic_pressure [Pa]                                    123798.692
# max_dynamic_pressure_time [s]                                     5.793
# max_acceleration_power_on [m/s²]                                101.030
# max_acceleration_power_on_time [s]                                3.131
# max_Gs_power_on [G]                                              10.302
# max_Gs_power_on_time [s]                                          3.131
# max_acceleration_power_off [m/s²]                                55.721
# max_acceleration_power_off_time [s]                               5.094
# max_Gs_power_off [G]                                              5.682
# max_Gs_power_off_time [s]                                         5.094
# max_stability_margin [calibers]                                   4.721
# impact_speed [m/s]                                               10.753
# impact_time [s]                                                 396.620
# impact_x [m]                                                   -968.454
# impact_y [m]                                                    684.444
# impact_lat [°]                                                    3.238
# impact_lon [°]                                                  -75.178
# impact_radius [m]                                              1185.904
#
#                                      ENV_normal_RL5.2_INC3_HDG90_ELEV436  \
# Variable
# initial_static_margin [calibers]                                   2.544
# frontal_surface_wind [m/s]                                       -10.000
# lateral_surface_wind [m/s]                                         0.000
# out_rail_vel [m/s]                                                25.122
# out_rail_stability [calibers]                                      2.607
# out_rail_angle_of_attack [deg]                                    21.276
# out_rail_thrust_to_weight [ratio]                                  8.956
# burn_out_dynamic_pressure [Pa]                                124102.169
# burn_out_time [s]                                                  5.820
# burn_out_accel [m/s²]                                             51.264
# apogee_alt [m]                                                  5940.995
# apogee_time [s]                                                   32.650
# max_speed [m/s]                                                  490.288
# max_speed_time [s]                                                 5.796
# max_mach [-]                                                       1.484
# max_mach_time [s]                                                  5.796
# max_dynamic_pressure [Pa]                                     124516.413
# max_dynamic_pressure_time [s]                                      5.794
# max_acceleration_power_on [m/s²]                                 101.137
# max_acceleration_power_on_time [s]                                 3.114
# max_Gs_power_on [G]                                               10.313
# max_Gs_power_on_time [s]                                           3.114
# max_acceleration_power_off [m/s²]                                 90.671
# max_acceleration_power_off_time [s]                                4.712
# max_Gs_power_off [G]                                               9.246
# max_Gs_power_off_time [s]                                          4.712
# max_stability_margin [calibers]                                    4.712
# impact_speed [m/s]                                                10.753
# impact_time [s]                                                  388.694
# impact_x [m]                                                    -331.887
# impact_y [m]                                                       0.000
# impact_lat [°]                                                     3.232
# impact_lon [°]                                                   -75.172
# impact_radius [m]                                                331.887
#
#                                      ENV_normal_RL5.2_INC3_HDG270_ELEV436  \
# Variable
# initial_static_margin [calibers]                                    2.544
# frontal_surface_wind [m/s]                                         10.000
# lateral_surface_wind [m/s]                                         -0.000
# out_rail_vel [m/s]                                                 25.122
# out_rail_stability [calibers]                                       2.606
# out_rail_angle_of_attack [deg]                                     22.095
# out_rail_thrust_to_weight [ratio]                                   8.956
# burn_out_dynamic_pressure [Pa]                                 122641.729
# burn_out_time [s]                                                   5.820
# burn_out_accel [m/s²]                                              50.986
# apogee_alt [m]                                                   6347.933
# apogee_time [s]                                                    33.869
# max_speed [m/s]                                                   489.839
# max_speed_time [s]                                                  5.799
# max_mach [-]                                                        1.480
# max_mach_time [s]                                                   5.799
# max_dynamic_pressure [Pa]                                      123056.229
# max_dynamic_pressure_time [s]                                       5.793
# max_acceleration_power_on [m/s²]                                  100.918
# max_acceleration_power_on_time [s]                                  3.143
# max_Gs_power_on [G]                                                10.291
# max_Gs_power_on_time [s]                                            3.143
# max_acceleration_power_off [m/s²]                                  86.411
# max_acceleration_power_off_time [s]                                 4.893
# max_Gs_power_off [G]                                                8.811
# max_Gs_power_off_time [s]                                           4.893
# max_stability_margin [calibers]                                     4.698
# impact_speed [m/s]                                                 10.753
# impact_time [s]                                                   404.901
# impact_x [m]                                                    -1647.425
# impact_y [m]                                                        0.000
# impact_lat [°]                                                      3.232
# impact_lon [°]                                                    -75.184
# impact_radius [m]                                                1647.425
#
#                                      ENV_normal_RL5.2_INC3_HDG45_ELEV436
# Variable
# initial_static_margin [calibers]                                   2.544
# frontal_surface_wind [m/s]                                        -7.071
# lateral_surface_wind [m/s]                                         7.071
# out_rail_vel [m/s]                                                25.122
# out_rail_stability [calibers]                                      2.607
# out_rail_angle_of_attack [deg]                                    21.406
# out_rail_thrust_to_weight [ratio]                                  8.956
# burn_out_dynamic_pressure [Pa]                                123889.766
# burn_out_time [s]                                                  5.820
# burn_out_accel [m/s²]                                             52.294
# apogee_alt [m]                                                  5997.277
# apogee_time [s]                                                   32.818
# max_speed [m/s]                                                  490.214
# max_speed_time [s]                                                 5.795
# max_mach [-]                                                       1.484
# max_mach_time [s]                                                  5.795
# max_dynamic_pressure [Pa]                                     124304.178
# max_dynamic_pressure_time [s]                                      5.794
# max_acceleration_power_on [m/s²]                                 101.106
# max_acceleration_power_on_time [s]                                 3.117
# max_Gs_power_on [G]                                               10.310
# max_Gs_power_on_time [s]                                           3.117
# max_acceleration_power_off [m/s²]                                 50.524
# max_acceleration_power_off_time [s]                                5.448
# max_Gs_power_off [G]                                               5.152
# max_Gs_power_off_time [s]                                          5.448
# max_stability_margin [calibers]                                    4.699
# impact_speed [m/s]                                                10.753
# impact_time [s]                                                  390.945
# impact_x [m]                                                    -514.373
# impact_y [m]                                                     470.307
# impact_lat [°]                                                     3.236
# impact_lon [°]                                                   -75.174
# impact_radius [m]                                                696.971

# %%
for i, key in enumerate(keys):
    print(f"--- Simulation {i}: {key} ---")
    multiple_files[keys[i]].plots.trajectory_3d()
# Out:
# --- Simulation 0: ENV_normal_RL5.2_INC3_HDG0_ELEV436 ---
# --- Simulation 1: ENV_normal_RL5.2_INC3_HDG90_ELEV436 ---
# --- Simulation 2: ENV_normal_RL5.2_INC3_HDG270_ELEV436 ---
# --- Simulation 3: ENV_normal_RL5.2_INC3_HDG45_ELEV436 ---

# %%
for i, key in enumerate(keys):
    print(f"--- Simulation {i}: {key} ---")
    multiple_files[keys[i]].prints.impact_conditions()
# Out:
# --- Simulation 0: ENV_normal_RL5.2_INC3_HDG0_ELEV436 ---
#
# Impact Conditions
#
# Time of impact: 396.620 s
# X impact: -968.454 m
# Y impact: 684.444 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2378152°
# Longitude: -75.1778804°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 1: ENV_normal_RL5.2_INC3_HDG90_ELEV436 ---
#
# Impact Conditions
#
# Time of impact: 388.694 s
# X impact: -331.887 m
# Y impact: 0.000 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2316667°
# Longitude: -75.1721528°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 2: ENV_normal_RL5.2_INC3_HDG270_ELEV436 ---
#
# Impact Conditions
#
# Time of impact: 404.901 s
# X impact: -1647.425 m
# Y impact: 0.000 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2316666°
# Longitude: -75.1839895°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
# --- Simulation 3: ENV_normal_RL5.2_INC3_HDG45_ELEV436 ---
#
# Impact Conditions
#
# Time of impact: 390.945 s
# X impact: -514.373 m
# Y impact: 470.307 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2358915°
# Longitude: -75.1737948°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2

# %%
for i, key in enumerate(keys):
    print(f"--- Simulation {i}: {key} ---")
    multiple_files[keys[i]].info()
# Out:
# --- Simulation 0: ENV_normal_RL5.2_INC3_HDG0_ELEV436 ---
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 436.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: -0.383 | e1: 0.010 | e2: 0.024 | e3: 0.924
# Euler Angles - Spin φ : 225.00° | Nutation θ: -3.00° | Precession ψ: 0.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.544 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -0.00 m/s
# Lateral Surface Wind Speed: 10.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 5.2 m
# Launch Rail Inclination: 87.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.349 s
# Rail Departure Velocity: 25.122 m/s
# Rail Departure Stability Margin: 2.606 c
# Rail Departure Angle of Attack: 21.705°
# Rail Departure Thrust-Weight Ratio: 8.956
# Rail Departure Reynolds Number: 3.131e+05
#
#
# Burn out State
#
# Burn out time: 5.820 s
# Altitude at burn out: 1889.489 m (ASL) | 1453.489 m (AGL)
# Rocket speed at burn out: 489.527 m/s
# Freestream velocity at burn out: 492.408 m/s
# Mach Number at burn out: 1.481
# Kinetic energy at burn out: 3.708e+06 J
#
#
# Apogee State
#
# Apogee Time: 33.238 s
# Apogee Altitude: 6573.977 m (ASL) | 6137.977 m (AGL)
# Apogee Freestream Speed: 68.553 m/s
# Apogee X position: 2484.508 m
# Apogee Y position: 643.115 m
# Apogee latitude: 3.2374437°
# Apogee longitude: -75.1468120°
#
#
# Parachute Events
#
# Parachute: Drogue Parachute
# 	Ejection time: 33.248 s
# 	Inflation time: 33.248 s
# 	Freestream speed at inflation: 68.548 m/s
# 	Altitude at inflation: 6573.977 m (ASL) | 6137.977 m (AGL)
# Parachute: Main Parachute
# 	Ejection time: 284.705 s
# 	Inflation time: 284.705 s
# 	Freestream speed at inflation: 19.876 m/s
# 	Altitude at inflation: 885.884 m (ASL) | 449.884 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 396.620 s
# X impact: -968.454 m
# Y impact: 684.444 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2378152°
# Longitude: -75.1778804°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 2.544 c at 0.00 s
# Out of Rail Stability Margin: 2.606 c at 0.35 s
# Maximum Stability Margin: 4.721 c at 9.09 s
# Minimum Stability Margin: 2.544 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 490.063 m/s at 5.80 s
# Maximum Mach Number: 1.482 Mach at 5.80 s
# Maximum Reynolds Number: 5.092e+06 at 5.68 s
# Maximum Dynamic Pressure: 1.238e+05 Pa at 5.79 s
# Maximum Acceleration During Motor Burn: 101.030 m/s² at 3.13 s
# Maximum Gs During Motor Burn: 10.302 g at 3.13 s
# Maximum Acceleration After Motor Burn: 55.721 m/s² at 5.09 s
# Maximum Gs After Motor Burn: 5.682 Gs at 5.09 s
# Maximum Stability Margin: 4.721 c at 9.09 s
# Maximum Upper Rail Button Normal Force: 7.278 N
# Maximum Upper Rail Button Shear Force: 0.000 N
# Maximum Lower Rail Button Normal Force: 38.665 N
# Maximum Lower Rail Button Shear Force: 0.000 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 711
# Number of Derivative Functions Evaluation: 160
# Average Function Evaluations per Time Step: 0.225
#
# --- Simulation 1: ENV_normal_RL5.2_INC3_HDG90_ELEV436 ---
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 436.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.383 | e1: 0.024 | e2: 0.010 | e3: 0.924
# Euler Angles - Spin φ : 225.00° | Nutation θ: -3.00° | Precession ψ: -90.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.544 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -10.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 5.2 m
# Launch Rail Inclination: 87.00°
# Launch Rail Heading: 90.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.349 s
# Rail Departure Velocity: 25.122 m/s
# Rail Departure Stability Margin: 2.607 c
# Rail Departure Angle of Attack: 21.276°
# Rail Departure Thrust-Weight Ratio: 8.956
# Rail Departure Reynolds Number: 3.187e+05
#
#
# Burn out State
#
# Burn out time: 5.820 s
# Altitude at burn out: 1866.315 m (ASL) | 1430.315 m (AGL)
# Rocket speed at burn out: 489.746 m/s
# Freestream velocity at burn out: 493.266 m/s
# Mach Number at burn out: 1.483
# Kinetic energy at burn out: 3.712e+06 J
#
#
# Apogee State
#
# Apogee Time: 32.650 s
# Apogee Altitude: 6376.995 m (ASL) | 5940.995 m (AGL)
# Apogee Freestream Speed: 80.136 m/s
# Apogee X position: 3031.615 m
# Apogee Y position: 0.000 m
# Apogee latitude: 3.2316663°
# Apogee longitude: -75.1418895°
#
#
# Parachute Events
#
# Parachute: Drogue Parachute
# 	Ejection time: 32.657 s
# 	Inflation time: 32.657 s
# 	Freestream speed at inflation: 80.132 m/s
# 	Altitude at inflation: 6376.995 m (ASL) | 5940.995 m (AGL)
# Parachute: Main Parachute
# 	Ejection time: 276.790 s
# 	Inflation time: 276.790 s
# 	Freestream speed at inflation: 19.876 m/s
# 	Altitude at inflation: 885.835 m (ASL) | 449.835 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 388.694 s
# X impact: -331.887 m
# Y impact: 0.000 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2316667°
# Longitude: -75.1721528°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 2.544 c at 0.00 s
# Out of Rail Stability Margin: 2.607 c at 0.35 s
# Maximum Stability Margin: 4.712 c at 9.04 s
# Minimum Stability Margin: 2.544 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 490.288 m/s at 5.80 s
# Maximum Mach Number: 1.484 Mach at 5.80 s
# Maximum Reynolds Number: 5.110e+06 at 5.69 s
# Maximum Dynamic Pressure: 1.245e+05 Pa at 5.79 s
# Maximum Acceleration During Motor Burn: 101.137 m/s² at 3.11 s
# Maximum Gs During Motor Burn: 10.313 g at 3.11 s
# Maximum Acceleration After Motor Burn: 90.671 m/s² at 4.71 s
# Maximum Gs After Motor Burn: 9.246 Gs at 4.71 s
# Maximum Stability Margin: 4.712 c at 9.04 s
# Maximum Upper Rail Button Normal Force: 0.000 N
# Maximum Upper Rail Button Shear Force: 7.390 N
# Maximum Lower Rail Button Normal Force: 0.000 N
# Maximum Lower Rail Button Shear Force: 39.264 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 630
# Number of Derivative Functions Evaluation: 160
# Average Function Evaluations per Time Step: 0.254
#
# --- Simulation 2: ENV_normal_RL5.2_INC3_HDG270_ELEV436 ---
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 436.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.924 | e1: 0.010 | e2: -0.024 | e3: -0.383
# Euler Angles - Spin φ : -135.00° | Nutation θ: -3.00° | Precession ψ: 90.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.544 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 10.00 m/s
# Lateral Surface Wind Speed: -0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 5.2 m
# Launch Rail Inclination: 87.00°
# Launch Rail Heading: 270.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.349 s
# Rail Departure Velocity: 25.122 m/s
# Rail Departure Stability Margin: 2.606 c
# Rail Departure Angle of Attack: 22.095°
# Rail Departure Thrust-Weight Ratio: 8.956
# Rail Departure Reynolds Number: 3.075e+05
#
#
# Burn out State
#
# Burn out time: 5.820 s
# Altitude at burn out: 1913.410 m (ASL) | 1477.410 m (AGL)
# Rocket speed at burn out: 489.291 m/s
# Freestream velocity at burn out: 491.513 m/s
# Mach Number at burn out: 1.478
# Kinetic energy at burn out: 3.705e+06 J
#
#
# Apogee State
#
# Apogee Time: 33.869 s
# Apogee Altitude: 6783.933 m (ASL) | 6347.933 m (AGL)
# Apogee Freestream Speed: 52.840 m/s
# Apogee X position: 1898.332 m
# Apogee Y position: 0.000 m
# Apogee latitude: 3.2316665°
# Apogee longitude: -75.1520863°
#
#
# Parachute Events
#
# Parachute: Drogue Parachute
# 	Ejection time: 33.876 s
# 	Inflation time: 33.876 s
# 	Freestream speed at inflation: 52.838 m/s
# 	Altitude at inflation: 6783.933 m (ASL) | 6347.933 m (AGL)
# Parachute: Main Parachute
# 	Ejection time: 293.010 s
# 	Inflation time: 293.010 s
# 	Freestream speed at inflation: 19.876 m/s
# 	Altitude at inflation: 885.788 m (ASL) | 449.788 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 404.901 s
# X impact: -1647.425 m
# Y impact: 0.000 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2316666°
# Longitude: -75.1839895°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 2.544 c at 0.00 s
# Out of Rail Stability Margin: 2.606 c at 0.35 s
# Maximum Stability Margin: 4.698 c at 8.88 s
# Minimum Stability Margin: 2.544 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 489.839 m/s at 5.80 s
# Maximum Mach Number: 1.480 Mach at 5.80 s
# Maximum Reynolds Number: 5.073e+06 at 5.63 s
# Maximum Dynamic Pressure: 1.231e+05 Pa at 5.79 s
# Maximum Acceleration During Motor Burn: 100.918 m/s² at 3.14 s
# Maximum Gs During Motor Burn: 10.291 g at 3.14 s
# Maximum Acceleration After Motor Burn: 86.411 m/s² at 4.89 s
# Maximum Gs After Motor Burn: 8.811 Gs at 4.89 s
# Maximum Stability Margin: 4.698 c at 8.88 s
# Maximum Upper Rail Button Normal Force: 0.000 N
# Maximum Upper Rail Button Shear Force: 7.142 N
# Maximum Lower Rail Button Normal Force: 0.000 N
# Maximum Lower Rail Button Shear Force: 37.943 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 660
# Number of Derivative Functions Evaluation: 160
# Average Function Evaluations per Time Step: 0.242
#
# --- Simulation 3: ENV_normal_RL5.2_INC3_HDG45_ELEV436 ---
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 436.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.000 | e1: 0.019 | e2: 0.019 | e3: 1.000
# Euler Angles - Spin φ : 225.00° | Nutation θ: -3.00° | Precession ψ: -45.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.544 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -7.07 m/s
# Lateral Surface Wind Speed: 7.07 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 5.2 m
# Launch Rail Inclination: 87.00°
# Launch Rail Heading: 45.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.349 s
# Rail Departure Velocity: 25.122 m/s
# Rail Departure Stability Margin: 2.607 c
# Rail Departure Angle of Attack: 21.406°
# Rail Departure Thrust-Weight Ratio: 8.956
# Rail Departure Reynolds Number: 3.171e+05
#
#
# Burn out State
#
# Burn out time: 5.820 s
# Altitude at burn out: 1873.015 m (ASL) | 1437.015 m (AGL)
# Rocket speed at burn out: 489.674 m/s
# Freestream velocity at burn out: 493.009 m/s
# Mach Number at burn out: 1.482
# Kinetic energy at burn out: 3.710e+06 J
#
#
# Apogee State
#
# Apogee Time: 32.818 s
# Apogee Altitude: 6433.277 m (ASL) | 5997.277 m (AGL)
# Apogee Freestream Speed: 77.032 m/s
# Apogee X position: 2875.056 m
# Apogee Y position: 443.712 m
# Apogee latitude: 3.2356523°
# Apogee longitude: -75.1432981°
#
#
# Parachute Events
#
# Parachute: Drogue Parachute
# 	Ejection time: 32.819 s
# 	Inflation time: 32.819 s
# 	Freestream speed at inflation: 77.031 m/s
# 	Altitude at inflation: 6433.277 m (ASL) | 5997.277 m (AGL)
# Parachute: Main Parachute
# 	Ejection time: 279.067 s
# 	Inflation time: 279.067 s
# 	Freestream speed at inflation: 19.876 m/s
# 	Altitude at inflation: 885.733 m (ASL) | 449.733 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 390.945 s
# X impact: -514.373 m
# Y impact: 470.307 m
# Altitude impact: 436.000 m (ASL) | -0.000 m (AGL)
# Latitude: 3.2358915°
# Longitude: -75.1737948°
# Vertical velocity at impact: -3.952 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 2.544 c at 0.00 s
# Out of Rail Stability Margin: 2.607 c at 0.35 s
# Maximum Stability Margin: 4.699 c at 8.92 s
# Minimum Stability Margin: 2.544 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 490.214 m/s at 5.80 s
# Maximum Mach Number: 1.484 Mach at 5.80 s
# Maximum Reynolds Number: 5.104e+06 at 5.67 s
# Maximum Dynamic Pressure: 1.243e+05 Pa at 5.79 s
# Maximum Acceleration During Motor Burn: 101.106 m/s² at 3.12 s
# Maximum Gs During Motor Burn: 10.310 g at 3.12 s
# Maximum Acceleration After Motor Burn: 50.524 m/s² at 5.45 s
# Maximum Gs After Motor Burn: 5.152 Gs at 5.45 s
# Maximum Stability Margin: 4.699 c at 8.92 s
# Maximum Upper Rail Button Normal Force: 5.208 N
# Maximum Upper Rail Button Shear Force: 5.201 N
# Maximum Lower Rail Button Normal Force: 27.668 N
# Maximum Lower Rail Button Shear Force: 27.630 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 678
# Number of Derivative Functions Evaluation: 160
# Average Function Evaluations per Time Step: 0.236
