# %%
import sims
import pandas as pd

# %%
file_name = "IREC_version1"
motor_name = "AeroTech_N2220DM"

file = sims.File_simulation(file_name, motor_name)
# Out:
# File and motor verified
# Creating rocket for IREC_version1 with motor AeroTech_N2220DM
# Rocket created and ready for simulation. WARNING: Parachutes not added.

# %%
file.graph_motor()
file.show_motor_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.03675 m
# Nozzle Throat Radius: 0.01 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0.0 m
# Grain Density: 1269.4646112306802 kg/m3
# Grain Outer Radius: 0.049 m
# Grain Inner Radius: 0.0245 m
# Grain Height: 1.046 m
# Grain Volume: 0.006 m3
# Grain Mass: 7.512 kg
#
# Motor Details
# Total Burning Time: 5.371 s
# Total Propellant Mass: 7.512 kg
# Structural Mass Ratio: 0.391
# Average Propellant Exhaust Velocity: 1441.821 m/s
# Average Thrust: 2016.563 N
# Maximum Thrust: 3063.078 N at 0.084 s after ignition.
# Total Impulse: 10830.961 Ns

# %%
file.graph_rocket()
file.show_rocket_info()
# Out:
# Inertia Details
#
# Rocket Mass: 20.272 kg (without motor)
# Rocket Dry Mass: 25.086 kg (with unloaded motor)
# Rocket Loaded Mass: 32.598 kg
# Rocket Structural Mass Ratio: 0.770
# Rocket Inertia (with unloaded motor) 11: 7.172 kg*m2
# Rocket Inertia (with unloaded motor) 22: 7.172 kg*m2
# Rocket Inertia (with unloaded motor) 33: 40.654 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0875 m
# Rocket Frontal Area: 0.024053 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.199 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.361 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.838 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.193 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 8.215/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.438 m
# Fins Center of Pressure position: 2.927 m
#
# Stability
#
# Center of Mass position (time=0): 1.922 m
# Center of Pressure position (time=0): 2.440 m
# Initial Static Margin (mach=0, time=0): 2.959 c
# Final Static Margin (mach=0, time=burn_out): 4.062 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.518 m

# %%
lat = 40.4168
lon = -3.7038
elev = 667  # Elevation in meters

env1 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=5)
env2 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=10)
env3 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=15)
env4 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=20)

envs = [env1, env2, env3, env4]
envs_names = ['0 deg', '90 deg', '180 deg', '270 deg']
rail_lengths = [5.7]
inclinations = [0]
headings = [0]
elevations = [0]


multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=envs_names,
    rail_lengths=rail_lengths,
    inclinations=inclinations,
    headings=headings,
    elevations=elevations
)

df = sims.compare_usual_important_data(multiple_files, keys)
# Out:
# Runnin sim0
# Simulation 0 completed
# Runnin sim1
# Simulation 1 completed
# Runnin sim2
# Simulation 2 completed
# Runnin sim3
# Simulation 3 completed

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
df
# Out:
#                                      ENV_0 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                               2.959
# frontal_surface_wind [m/s]                                     5.000
# lateral_surface_wind [m/s]                                     0.000
# out_rail_vel [m/s]                                            26.187
# out_rail_stability [calibers]                                  3.039
# out_rail_angle_of_attack [deg]                                10.809
# out_rail_thrust_to_weight [ratio]                              8.445
# burn_out_dynamic_pressure [Pa]                             39181.176
# burn_out_time [s]                                              5.371
# burn_out_accel [m/s²]                                         27.181
# apogee_alt [m]                                              3166.363
# apogee_time [s]                                               25.008
# max_speed [m/s]                                              289.767
# max_speed_time [s]                                             4.486
# max_mach [-]                                                   0.868
# max_mach_time [s]                                              4.486
# max_dynamic_pressure [Pa]                                  45224.894
# max_dynamic_pressure_time [s]                                  4.435
# max_acceleration_power_on [m/s²]                              83.841
# max_acceleration_power_on_time [s]                             0.085
# max_Gs_power_on [G]                                            8.549
# max_Gs_power_on_time [s]                                       0.085
# max_acceleration_power_off [m/s²]                              0.000
# max_acceleration_power_off_time [s]                            0.000
# max_Gs_power_off [G]                                           0.000
# max_Gs_power_off_time [s]                                      0.000
# max_stability_margin [calibers]                                4.371
# impact_speed [m/s]                                           179.655
# impact_time [s]                                               53.460
#
#                                      ENV_90 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                2.959
# frontal_surface_wind [m/s]                                     10.000
# lateral_surface_wind [m/s]                                      0.000
# out_rail_vel [m/s]                                             26.185
# out_rail_stability [calibers]                                   3.039
# out_rail_angle_of_attack [deg]                                 20.902
# out_rail_thrust_to_weight [ratio]                               8.445
# burn_out_dynamic_pressure [Pa]                              39747.791
# burn_out_time [s]                                               5.371
# burn_out_accel [m/s²]                                          27.169
# apogee_alt [m]                                               2993.902
# apogee_time [s]                                                24.264
# max_speed [m/s]                                               289.080
# max_speed_time [s]                                              4.482
# max_mach [-]                                                    0.872
# max_mach_time [s]                                               4.482
# max_dynamic_pressure [Pa]                                   45773.720
# max_dynamic_pressure_time [s]                                   4.435
# max_acceleration_power_on [m/s²]                               83.826
# max_acceleration_power_on_time [s]                              0.085
# max_Gs_power_on [G]                                             8.548
# max_Gs_power_on_time [s]                                        0.085
# max_acceleration_power_off [m/s²]                               0.000
# max_acceleration_power_off_time [s]                             0.000
# max_Gs_power_off [G]                                            0.000
# max_Gs_power_off_time [s]                                       0.000
# max_stability_margin [calibers]                                 4.371
# impact_speed [m/s]                                            176.834
# impact_time [s]                                                51.969
#
#                                      ENV_180 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                 2.960
# frontal_surface_wind [m/s]                                      15.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              26.181
# out_rail_stability [calibers]                                    3.040
# out_rail_angle_of_attack [deg]                                  29.810
# out_rail_thrust_to_weight [ratio]                                8.445
# burn_out_dynamic_pressure [Pa]                               40654.115
# burn_out_time [s]                                                5.371
# burn_out_accel [m/s²]                                           27.187
# apogee_alt [m]                                                2737.214
# apogee_time [s]                                                 23.171
# max_speed [m/s]                                                287.995
# max_speed_time [s]                                               4.468
# max_mach [-]                                                     0.879
# max_mach_time [s]                                                4.506
# max_dynamic_pressure [Pa]                                    46656.117
# max_dynamic_pressure_time [s]                                    4.431
# max_acceleration_power_on [m/s²]                                83.888
# max_acceleration_power_on_time [s]                               0.085
# max_Gs_power_on [G]                                              8.554
# max_Gs_power_on_time [s]                                         0.085
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.000
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.000
# max_stability_margin [calibers]                                  4.371
# impact_speed [m/s]                                             172.369
# impact_time [s]                                                 49.653
#
#                                      ENV_270 deg_RL5.7_INC0_HDG0_ELEV0
# Variable
# initial_static_margin [calibers]                                 2.960
# frontal_surface_wind [m/s]                                      20.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              26.176
# out_rail_stability [calibers]                                    3.040
# out_rail_angle_of_attack [deg]                                  37.382
# out_rail_thrust_to_weight [ratio]                                8.445
# burn_out_dynamic_pressure [Pa]                               41854.188
# burn_out_time [s]                                                5.371
# burn_out_accel [m/s²]                                           27.210
# apogee_alt [m]                                                2431.638
# apogee_time [s]                                                 21.857
# max_speed [m/s]                                                286.652
# max_speed_time [s]                                               4.471
# max_mach [-]                                                     0.888
# max_mach_time [s]                                                4.501
# max_dynamic_pressure [Pa]                                    47835.902
# max_dynamic_pressure_time [s]                                    4.441
# max_acceleration_power_on [m/s²]                                84.225
# max_acceleration_power_on_time [s]                               0.084
# max_Gs_power_on [G]                                              8.589
# max_Gs_power_on_time [s]                                         0.084
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.000
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.000
# max_stability_margin [calibers]                                  4.371
# impact_speed [m/s]                                             166.517
# impact_time [s]                                                 46.767

# %%
multiple_files[keys[0]].plots.trajectory_3d()

# %%
env1.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8000 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5598 m/s²
#
#
# Launch Site Details
#
# Launch Site Latitude: 40.41680°
# Launch Site Longitude: -3.70380°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 440290.46 W    4474257.38 N
# Launch Site UTM zone: 30T
# Launch Site Surface Elevation: 667.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: custom_atmosphere
# custom_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 5.00 m/s
# Surface Wind Direction: 180.00°
# Surface Wind Heading: 360.00°
# Surface Pressure: 935.78 hPa
# Surface Temperature: 283.82 K
# Surface Air Density: 1.149 kg/m³
# Surface Speed of Sound: 337.56 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.19 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
