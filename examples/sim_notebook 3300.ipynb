# %%
import sims
import pandas as pd
from rocketpy import Environment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sims
#       2 import pandas as pd
#       3 from rocketpy import Environment
#
# ModuleNotFoundError: No module named 'sims'

# %%
file_name = "IREC_version1"
motor_name = "AeroTech_N3300R"

file = sims.File_simulation(file_name, motor_name)
# Out:
# File and motor verified
# Creating rocket for IREC_version1 with motor AeroTech_N3300R
# Rocket created and ready for simulation. WARNING: Parachutes not added.

# %%
file.graph_motor()
file.show_motor_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.03675 m
# Nozzle Throat Radius: 0.01 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0.0 m
# Grain Density: 1269.4646112306802 kg/m3
# Grain Outer Radius: 0.049 m
# Grain Inner Radius: 0.0245 m
# Grain Height: 1.046 m
# Grain Volume: 0.006 m3
# Grain Mass: 7.512 kg
#
# Motor Details
# Total Burning Time: 4.519 s
# Total Propellant Mass: 7.512 kg
# Structural Mass Ratio: 0.377
# Average Propellant Exhaust Velocity: 1868.363 m/s
# Average Thrust: 3105.808 N
# Maximum Thrust: 3775.78 N at 0.125 s after ignition.
# Total Impulse: 14035.146 Ns

# %%
file.graph_rocket()
file.show_rocket_info()
# Out:
# Inertia Details
#
# Rocket Mass: 20.272 kg (without motor)
# Rocket Dry Mass: 24.814 kg (with unloaded motor)
# Rocket Loaded Mass: 32.326 kg
# Rocket Structural Mass Ratio: 0.768
# Rocket Inertia (with unloaded motor) 11: 6.820 kg*m2
# Rocket Inertia (with unloaded motor) 22: 6.820 kg*m2
# Rocket Inertia (with unloaded motor) 33: 40.382 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0875 m
# Rocket Frontal Area: 0.024053 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.190 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.370 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.847 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.197 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 8.215/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.438 m
# Fins Center of Pressure position: 2.927 m
#
# Stability
#
# Center of Mass position (time=0): 1.917 m
# Center of Pressure position (time=0): 2.440 m
# Initial Static Margin (mach=0, time=0): 2.990 c
# Final Static Margin (mach=0, time=burn_out): 4.115 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.523 m

# %%
lat = 40.4168
lon = -3.7038
elev = 667  # Elevation in meters

env1 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=5)
env2 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=10)
env3 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=15)
env4 = sims.generate_cte_wind_cte_angle(lat=lat, lon=lon, elev=elev, angle=180, speed=20)

env5 = Environment(
    date=(2019, 8, 10, 21),
    latitude=31.0525,
    longitude=-103.54467,
    elevation=891,
)

envs = [env5]#[env1, env2, env3, env4]
#env5.info()

alts = [0, 800, 1300, 2000, 4000]
angles = [120, 130, 250, 250, 250]
vels = [10, 15, 10, 7, 7]

env6 = sims.generate_variable_wind_profile(lat=lat, lon=lon, elev=elev, heights_ref=alts, angles_ref=angles, speeds_ref=vels)
env6.info()

env_names = ["normal"]
envs_names = ['0 deg', '90 deg', '180 deg', '270 deg']

rail_lengths = [5.7]
inclinations = [0,2,3,6]
headings = [0]
elevations = [0]


""" multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=envs_names,
    rail_lengths=rail_lengths,
    inclinations=inclinations,
    headings=headings,
    elevations=elevations
)

df = sims.compare_usual_important_data(multiple_files, keys) """
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8000 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5598 m/s²
#
#
# Launch Site Details
#
# Launch Site Latitude: 40.41680°
# Launch Site Longitude: -3.70380°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 440290.46 W    4474257.38 N
# Launch Site UTM zone: 30T
# Launch Site Surface Elevation: 667.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: custom_atmosphere
# custom_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 3.22 m/s
# Surface Wind Direction: 120.00°
# Surface Wind Heading: 300.00°
# Surface Pressure: 935.78 hPa
# Surface Temperature: 283.82 K
# Surface Air Density: 1.149 kg/m³
# Surface Speed of Sound: 337.56 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.19 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
# ' multiple_files, keys = file.run_multiple_flight_sims(envs=envs, envs_names=envs_names,\n    rail_lengths=rail_lengths,\n    inclinations=inclinations,\n    headings=headings,\n    elevations=elevations\n)\n\ndf = sims.compare_usual_important_data(multiple_files, keys) '

# %%
pd.set_option('display.float_format', lambda x: f'{x:.3f}')
df
# Out:
#                                      ENV_0 deg_RL5.7_INC0_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                               2.990
# frontal_surface_wind [m/s]                                     0.000
# lateral_surface_wind [m/s]                                     0.000
# out_rail_vel [m/s]                                            31.413
# out_rail_stability [calibers]                                  3.063
# out_rail_angle_of_attack [deg]                                -0.000
# out_rail_thrust_to_weight [ratio]                             11.521
# burn_out_dynamic_pressure [Pa]                             75063.644
# burn_out_time [s]                                              4.519
# burn_out_accel [m/s²]                                         43.511
# apogee_alt [m]                                              4463.138
# apogee_time [s]                                               28.405
# max_speed [m/s]                                              514.509
# max_speed_time [s]                                            54.552
# max_mach [-]                                                   1.528
# max_mach_time [s]                                             54.552
# max_dynamic_pressure [Pa]                                 148707.204
# max_dynamic_pressure_time [s]                                 54.552
# max_acceleration_power_on [m/s²]                             109.068
# max_acceleration_power_on_time [s]                             1.382
# max_Gs_power_on [G]                                           11.122
# max_Gs_power_on_time [s]                                       1.382
# max_acceleration_power_off [m/s²]                            108.395
# max_acceleration_power_off_time [s]                            0.980
# max_Gs_power_off [G]                                          11.053
# max_Gs_power_off_time [s]                                      0.980
# max_stability_margin [calibers]                                4.502
# impact_speed [m/s]                                           514.509
# impact_time [s]                                               54.552
#
#                                      ENV_90 deg_RL5.7_INC2_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                2.990
# frontal_surface_wind [m/s]                                      0.000
# lateral_surface_wind [m/s]                                      0.000
# out_rail_vel [m/s]                                             31.403
# out_rail_stability [calibers]                                   3.063
# out_rail_angle_of_attack [deg]                                  0.000
# out_rail_thrust_to_weight [ratio]                              11.521
# burn_out_dynamic_pressure [Pa]                              75081.713
# burn_out_time [s]                                               4.519
# burn_out_accel [m/s²]                                          43.474
# apogee_alt [m]                                               4456.269
# apogee_time [s]                                                28.389
# max_speed [m/s]                                               390.598
# max_speed_time [s]                                              4.292
# max_mach [-]                                                    1.173
# max_mach_time [s]                                               4.292
# max_dynamic_pressure [Pa]                                   78360.142
# max_dynamic_pressure_time [s]                                   4.264
# max_acceleration_power_on [m/s²]                              109.108
# max_acceleration_power_on_time [s]                              1.487
# max_Gs_power_on [G]                                            11.126
# max_Gs_power_on_time [s]                                        1.487
# max_acceleration_power_off [m/s²]                               0.000
# max_acceleration_power_off_time [s]                             0.000
# max_Gs_power_off [G]                                            0.000
# max_Gs_power_off_time [s]                                       0.000
# max_stability_margin [calibers]                                 4.502
# impact_speed [m/s]                                            194.024
# impact_time [s]                                                63.195
#
#                                      ENV_180 deg_RL5.7_INC3_HDG0_ELEV0  \
# Variable
# initial_static_margin [calibers]                                 2.990
# frontal_surface_wind [m/s]                                       0.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              31.418
# out_rail_stability [calibers]                                    3.063
# out_rail_angle_of_attack [deg]                                   0.000
# out_rail_thrust_to_weight [ratio]                               11.521
# burn_out_dynamic_pressure [Pa]                               75099.710
# burn_out_time [s]                                                4.519
# burn_out_accel [m/s²]                                           43.541
# apogee_alt [m]                                                4447.572
# apogee_time [s]                                                 28.364
# max_speed [m/s]                                                390.609
# max_speed_time [s]                                               4.297
# max_mach [-]                                                     1.173
# max_mach_time [s]                                                4.297
# max_dynamic_pressure [Pa]                                    78378.912
# max_dynamic_pressure_time [s]                                    4.249
# max_acceleration_power_on [m/s²]                               109.117
# max_acceleration_power_on_time [s]                               1.482
# max_Gs_power_on [G]                                             11.127
# max_Gs_power_on_time [s]                                         1.482
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.001
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.001
# max_stability_margin [calibers]                                  4.507
# impact_speed [m/s]                                             193.969
# impact_time [s]                                                 63.080
#
#                                      ENV_270 deg_RL5.7_INC6_HDG0_ELEV0
# Variable
# initial_static_margin [calibers]                                 2.990
# frontal_surface_wind [m/s]                                       0.000
# lateral_surface_wind [m/s]                                       0.000
# out_rail_vel [m/s]                                              31.437
# out_rail_stability [calibers]                                    3.063
# out_rail_angle_of_attack [deg]                                   0.000
# out_rail_thrust_to_weight [ratio]                               11.521
# burn_out_dynamic_pressure [Pa]                               75208.865
# burn_out_time [s]                                                4.519
# burn_out_accel [m/s²]                                           43.456
# apogee_alt [m]                                                4400.878
# apogee_time [s]                                                 28.193
# max_speed [m/s]                                                390.781
# max_speed_time [s]                                               4.296
# max_mach [-]                                                     1.174
# max_mach_time [s]                                                4.296
# max_dynamic_pressure [Pa]                                    78478.979
# max_dynamic_pressure_time [s]                                    4.244
# max_acceleration_power_on [m/s²]                               109.170
# max_acceleration_power_on_time [s]                               1.482
# max_Gs_power_on [G]                                             11.132
# max_Gs_power_on_time [s]                                         1.482
# max_acceleration_power_off [m/s²]                                0.000
# max_acceleration_power_off_time [s]                              0.001
# max_Gs_power_off [G]                                             0.000
# max_Gs_power_off_time [s]                                        0.001
# max_stability_margin [calibers]                                  4.511
# impact_speed [m/s]                                             193.603
# impact_time [s]                                                 62.726

# %%
multiple_files[keys[0]].plots.trajectory_3d()

# %%
env1.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8000 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5598 m/s²
#
#
# Launch Site Details
#
# Launch Site Latitude: 40.41680°
# Launch Site Longitude: -3.70380°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 440290.46 W    4474257.38 N
# Launch Site UTM zone: 30T
# Launch Site Surface Elevation: 667.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: custom_atmosphere
# custom_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 5.00 m/s
# Surface Wind Direction: 180.00°
# Surface Wind Heading: 360.00°
# Surface Pressure: 935.78 hPa
# Surface Temperature: 283.82 K
# Surface Air Density: 1.149 kg/m³
# Surface Speed of Sound: 337.56 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.19 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
